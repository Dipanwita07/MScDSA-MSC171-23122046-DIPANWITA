# %%
import random

# Creating a lists of items, quantities, and prices

items = ["rice", "chicken", "coffee", "tea", "momo", "pizza", "burger", "sandwich", "bread", "biscuit"]
quantities = [random.randint(1, 10) for _ in range(10)]
prices = [round(random.uniform(1, 10), 2) for _ in range(10)]


# Create and write to a CSV file (as a text file)

with open('23122039.txt', 'w') as txtfile:
    txtfile.write("Item,Quantity,UnitPrice,TotalCost\n")

    for _ in range(100):
        r1 = random.randint(0, 9)
        quantity = quantities[r1]
        price_perUnit = prices[r1]
        total_cost = round(quantity * price_perUnit, 2)
        txtfile.write(f"{items[r1]},{quantity},{price_perUnit},{total_cost}\n")



# Read the text file and print results

with open('23122039.txt', 'r') as txtfile:
    next(txtfile)  # to exclude the row that contains headers

    # Initialize lists to store data

    rows = [line.strip().split(',') for line in txtfile]
    unq_items = set([row[0] for row in rows])

    # Print results for the first 5 rows and last 10 rows

    print("Results for the first 5 rows:")
    for row in rows[:5]:
        print(f"Item: {row[0]}, Quantity: {row[1]}, Total Cost: {row[3]}")

    print("\nResults for the last 10 rows:")
    for row in rows[-10:]:
        print(f"Item: {row[0]}, Quantity: {row[1]}, Total Cost: {row[3]}")


    # Calculate and print total cost for each unique item

    print("\nTotal cost for each unique item:")
    for item in unq_items:
        total_quantity = sum(int(row[1]) for row in rows if row[0] == item)
        total_cost = sum(float(row[3]) for row in rows if row[0] == item)
        print(f"Item Name: {item}, Total Quantity: {total_quantity}, Total Cost: {total_cost}")


    # Calculate and print min and max prices for each item sold
    
    print("\nMinimum and Maximum Prices for Each Item Sold:")
    for item in items:
        item_prices = [float(row[2]) for row in rows if row[0] == item]
        min_price = min(item_prices)
        max_price = max(item_prices)
        print(f"Item: {item}, Min Price: {min_price}, Max Price: {max_price}")
# Out:
# Results for the first 5 rows:
# Item: coffee, Quantity: 5, Total Cost: 48.15
# Item: sandwich, Quantity: 1, Total Cost: 6.32
# Item: pizza, Quantity: 8, Total Cost: 35.92
# Item: biscuit, Quantity: 1, Total Cost: 3.2
# Item: chicken, Quantity: 2, Total Cost: 6.92
#
# Results for the last 10 rows:
# Item: pizza, Quantity: 8, Total Cost: 35.92
# Item: pizza, Quantity: 8, Total Cost: 35.92
# Item: momo, Quantity: 2, Total Cost: 9.32
# Item: tea, Quantity: 4, Total Cost: 18.72
# Item: pizza, Quantity: 8, Total Cost: 35.92
# Item: chicken, Quantity: 2, Total Cost: 6.92
# Item: tea, Quantity: 4, Total Cost: 18.72
# Item: pizza, Quantity: 8, Total Cost: 35.92
# Item: burger, Quantity: 1, Total Cost: 7.75
# Item: burger, Quantity: 1, Total Cost: 7.75
#
# Total cost for each unique item:
# Item Name: sandwich, Total Quantity: 8, Total Cost: 50.56
# Item Name: coffee, Total Quantity: 70, Total Cost: 674.0999999999998
# Item Name: pizza, Total Quantity: 112, Total Cost: 502.88000000000017
# Item Name: bread, Total Quantity: 15, Total Cost: 147.75
# Item Name: tea, Total Quantity: 24, Total Cost: 112.32
# Item Name: momo, Total Quantity: 22, Total Cost: 102.51999999999998
# Item Name: burger, Total Quantity: 15, Total Cost: 116.25
# Item Name: chicken, Total Quantity: 12, Total Cost: 41.52
# Item Name: rice, Total Quantity: 21, Total Cost: 182.48999999999998
# Item Name: biscuit, Total Quantity: 14, Total Cost: 44.800000000000004
#
# Minimum and Maximum Prices for Each Item Sold:
# Item: rice, Min Price: 8.69, Max Price: 8.69
# Item: chicken, Min Price: 3.46, Max Price: 3.46
# Item: coffee, Min Price: 9.63, Max Price: 9.63
# Item: tea, Min Price: 4.68, Max Price: 4.68
# Item: momo, Min Price: 4.66, Max Price: 4.66
# Item: pizza, Min Price: 4.49, Max Price: 4.49
# Item: burger, Min Price: 7.75, Max Price: 7.75
# Item: sandwich, Min Price: 6.32, Max Price: 6.32
# Item: bread, Min Price: 9.85, Max Price: 9.85
# Item: biscuit, Min Price: 3.2, Max Price: 3.2
